# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Netflix TV Shows and Movies.csv")
df
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   object
#  2   title              5283 non-null   object
#  3   type               5283 non-null   object
#  4   description        5278 non-null   object
#  5   release_year       5283 non-null   int64
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5267 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %%
df.isnull().sum()
# Out:
# index                   0
# id                      0
# title                   0
# type                    0
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             16
# dtype: int64

# %%
df.fillna(999,inplace=True)

# %%
df.isnull().sum()
# Out:
# index                0
# id                   0
# title                0
# type                 0
# description          0
# release_year         0
# age_certification    0
# runtime              0
# imdb_id              0
# imdb_score           0
# imdb_votes           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   int64
#  1   id                 5283 non-null   object
#  2   title              5283 non-null   object
#  3   type               5283 non-null   object
#  4   description        5283 non-null   object
#  5   release_year       5283 non-null   int64
#  6   age_certification  5283 non-null   object
#  7   runtime            5283 non-null   int64
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5283 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 454.1+ KB

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'imdb_id', 'imdb_score', 'imdb_votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (5283, 11)

# %%
# 6. Q: How do you get the data types of each column?

df.dtypes
# Out:
# index                  int64
# id                    object
# title                 object
# type                  object
# description           object
# release_year           int64
# age_certification     object
# runtime                int64
# imdb_id               object
# imdb_score           float64
# imdb_votes           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'imdb_id', 'imdb_score', 'imdb_votes'],
#       dtype='object')

# %%
# 1. Print all movie titles using a for loop

for title in df['title']:
    print(title)
# Out:
# Taxi Driver
# Monty Python and the Holy Grail
# Life of Brian
# The Exorcist
# Monty Python's Flying Circus
# Dirty Harry
# My Fair Lady
# The Blue Lagoon
# Bonnie and Clyde
# The Professionals
# The Guns of Navarone
# Lupin the Third: The Castle of Cagliostro
# Richard Pryor: Live in Concert
# The Long Riders
# White Christmas
# Cairo Station
# The Queen
# Hitler: A Career
# FTA
# Saladin the Victorious
# Singapore
# Dark Waters
# Alexandriaâ€¦ Why?
# Raya and Sakina
# No Longer Kids
# Amrapali
# Dostana
# The Blazing Sun
# Monty Python's Fliegender Zirkus
# The Return of the Prodigal Son
# Prince
# Manoranjan
# Beirut, Oh Beirut
# We Are All for the Fatherland
# Whispers
# Lal Patthar
# Ujala
# Alibaba Aur 40 Chor
# Professor
# Chadi Jawani Budhe Nu
# Bandie
# Khoon Khoon
# Top Gun
# Seinfeld
# Stand by Me
# Once Upon a Time in America
# When Harry Met Sally...
# Teenage Mutant Ninja Turtles
# Full Metal Jacket
# Christine
# A Nightmare on Elm Street
# Knight Rider
# Awakenings
# ...

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'imdb_id', 'imdb_score', 'imdb_votes'],
#       dtype='object')

# %%
#2. Print all movies released after 2015

for i in range(len(df)):
    if df['release_year'][i]>2015:
        print(df['release_year'][i])
# Out:
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# ...

# %%
# Q1.Q2. How to display the first 5 rows?
df.head()
# Out:
#    index        id                            title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
# 3      3  tm190788                     The Exorcist  MOVIE
# 4      4   ts22164     Monty Python's Flying Circus   SHOW
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
# 3  12-year-old Regan MacNeil begins to adapt an e...          1973
# 4  A British sketch comedy series with the shows ...          1969
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0
# 1                PG       91  tt0071853         8.2    530877.0
# ...

# %%
#Q3. How to check DataFrame shape?


df.shape
# Out:
# (5283, 11)

# %%
# Q4. How to get column names?

df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'imdb_id', 'imdb_score', 'imdb_votes'],
#       dtype='object')

# %%
#Q5. How to check for missing values?

df.isnull().sum()
# Out:
# index                0
# id                   0
# title                0
# type                 0
# description          0
# release_year         0
# age_certification    0
# runtime              0
# imdb_id              0
# imdb_score           0
# imdb_votes           0
# dtype: int64

# %%
# Q6. How to get summary statistics for numerical columns?

df.describe()
# Out:
#              index  release_year      runtime   imdb_score    imdb_votes
# count  5283.000000   5283.000000  5283.000000  5283.000000  5.283000e+03
# mean   2641.000000   2015.879992    79.199886     6.533447  2.333933e+04
# std    1525.215067      7.346098    38.915974     1.160932  8.701096e+04
# min       0.000000   1953.000000     0.000000     1.500000  5.000000e+00
# 25%    1320.500000   2015.000000    45.000000     5.800000  5.220000e+02
# 50%    2641.000000   2018.000000    87.000000     6.600000  2.256000e+03
# 75%    3961.500000   2020.000000   106.000000     7.400000  1.009700e+04
# max    5282.000000   2022.000000   235.000000     9.600000  2.268288e+06

# %%
# Q7. How to display all unique type values?

df['type'].unique()
# Out:
# array(['MOVIE', 'SHOW'], dtype=object)

# %%
# 8. How to count number of movies vs shows?

df['type'].value_counts()
# Out:
# type
# MOVIE    3407
# SHOW     1876
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'imdb_id', 'imdb_score', 'imdb_votes'],
#       dtype='object')

# %%
#Q9. How to filter movies released after 2015?

df[df['release_year'] > 2015]
# Out:
#       index         id                               title   type  \
# 1145   1145    ts38796                     Stranger Things   SHOW
# 1149   1149    ts41766                      The Good Place   SHOW
# 1153   1153    ts41961                  Queen of the South   SHOW
# 1154   1154    ts42069                           The Crown   SHOW
# 1156   1156   tm232579           Hunt for the Wilderpeople  MOVIE
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 1145  When a young boy vanishes, a small town uncove...          2016
# ...

# %%
#Q10. How to select only title and imdb_score columns?

df[['title','imdb_score']]
# Out:
#                                    title  imdb_score
# 0                            Taxi Driver         8.3
# 1        Monty Python and the Holy Grail         8.2
# 2                          Life of Brian         8.0
# 3                           The Exorcist         8.1
# 4           Monty Python's Flying Circus         8.8
# ...                                  ...         ...
# 5278         Momshies! Your Soul is Mine         5.8
# 5279                           Fine Wine         6.9
# 5280                               Clash         6.5
# 5281                      Shadow Parties         6.2
# 5282  Mighty Little Bheem: Kite Festival         8.8
#
# [5283 rows x 2 columns]

# %%
# Q11. How to sort by IMDb score in descending order?

df.sort_values(by='imdb_score',ascending = False)
# Out:
#       index        id                              title   type  \
# 622     622  ts160526                           Khawatir   SHOW
# 2787   2787  ts265844                           #ABtalks   SHOW
# 229     229       ts4                       Breaking Bad   SHOW
# 3144   3144   ts85398                         Our Planet   SHOW
# 3597   3597   ts90621                       Kota Factory   SHOW
# ...     ...       ...                                ...    ...
# 4782   4782  ts280693  Thomas & Friends: All Engines Go!   SHOW
# 1101   1101  tm171891                         Himmatwala  MOVIE
# 3355   3355  tm839411   Me Against You: Mr. S's Vendetta  MOVIE
# 4648   4648  ts319303                     He's Expecting   SHOW
# 1664   1664  tm549892                            Aerials  MOVIE
#
#                                             description  release_year  \
# 622   A TV show devoted to help young people to be m...          2005
# ...

# %%
# Q12. How to get top 10 highest-rated movies?

df.nlargest(10,'imdb_score')
# Out:
#       index        id                       title  type  \
# 622     622  ts160526                    Khawatir  SHOW
# 2787   2787  ts265844                    #ABtalks  SHOW
# 229     229       ts4                Breaking Bad  SHOW
# 245     245    ts3371  Avatar: The Last Airbender  SHOW
# 3144   3144   ts85398                  Our Planet  SHOW
# 3597   3597   ts90621                Kota Factory  SHOW
# 1346   1346   ts37660                  Reply 1988  SHOW
# 1953   1953   ts78298                   My Mister  SHOW
# 4628   4628  ts296563         Who Rules The World  SHOW
# 3026   3026   ts81120              The Last Dance  SHOW
#
#                                             description  release_year  \
# 622   A TV show devoted to help young people to be m...          2005
# 2787  #ABtalks is a YouTube interview show hosted by...          2018
# 229   When Walter White, a New Mexico chemistry teac...          2008
# ...

# %%
# Q13. How to count total rows where imdb_score is above 8?

df[df['imdb_score'] >8].shape[0]
# Out:
# 404

# %%
#Q14. How to find average runtime?

df['runtime'].mean()
# Out:
# np.float64(79.19988642816581)

# %%
# Q15. How to find the earliest release year?
df['release_year'].min()
# Out:
# 1953

# %%
#Q16. How to find the latest release year?

df['release_year'].max()
# Out:
# 2022

# %%
#. How to filter rows where title contains "Love"?

df[df['title'].str.contains('Love', case=False, na=False)]
# Out:
#       index         id                     title   type  \
# 59       59   tm130586              Endless Love  MOVIE
# 272     272   tm133767             Love Actually  MOVIE
# 418     418   tm137530              Love Happens  MOVIE
# 479     479    tm65839   Just Another Love Story  MOVIE
# 497     497    tm95434            Love in a Puff  MOVIE
# ...     ...        ...                       ...    ...
# 5113   5113  tm1037704            Resort to Love  MOVIE
# 5116   5116  tm1001619               Man in Love  MOVIE
# 5134   5134  tm1000185              Squared Love  MOVIE
# 5143   5143  tm1027712  This Little Love of Mine  MOVIE
# 5184   5184  tm1055586               Lethal Love  MOVIE
#
#                                             description  release_year  \
# 59    Two young kids fall in love with each other. B...          1981
# 272   'Love Actually' follows the lives of eight ver...          2003
# 418   Dr. Burke Ryan is a successful self-help autho...          2009
# ...

# %%
df['runtime'].fillna(df['runtime'].mean(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12188\1799550276.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['runtime'].fillna(df['runtime'].mean(), inplace=True)

# %%
## Q19. How to drop rows with missing imdb_score?

df.dropna(subset=['imdb_score'],inplace=True)

# %%
#Q20. How to rename column runtime to runtime_minutes?

df.rename(columns={'runtime':'runtime_minutes'}, inplace = True)

# %%
## 21. How to group by release_year and get average IMDb score?
df.groupby('release_year')['imdb_score'].mean()
# Out:
# release_year
# 1953    6.800000
# 1954    7.450000
# 1956    6.700000
# 1958    7.500000
# 1959    6.700000
#           ...
# 2018    6.530559
# 2019    6.526168
# 2020    6.344444
# 2021    6.319068
# 2022    6.263187
# Name: imdb_score, Length: 66, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes'],
#       dtype='object')

# %%
#Q22. How to get the highest-rated movie each year?

df.groupby('release_year')['imdb_score'].idxmax()
# Out:
# release_year
# 1953      23
# 1954      14
# 1956      21
# 1958      15
# 1959      36
#         ...
# 2018    2787
# 2019    3144
# 2020    3026
# 2021    4429
# 2022    4628
# Name: imdb_score, Length: 66, dtype: int64

# %%
#Q23. How to plot IMDb sct seaborn as sns

sns.histplot(df['imdb_score'], bins=20,kde=True)
# Out:
# <Axes: xlabel='imdb_score', ylabel='Count'>

# %%
#Q24. How to plot average IMDb score per release year?

sns.lineplot(x='release_year',y='imdb_score',data=df)
# Out:
# <Axes: xlabel='release_year', ylabel='imdb_score'>

# %%
#Q25. How to find movies with runtime over 3 hours?

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes'],
#       dtype='object')

# %%
df[df['runtime_minutes']>180]
# Out:
#       index        id                              title   type  \
# 19       19   tm27298             Saladin the Victorious  MOVIE
# 24       24   tm76557                     No Longer Kids  MOVIE
# 45       45  tm180542        Once Upon a Time in America  MOVIE
# 176     176   tm67635                 Kuch Kuch Hota Hai  MOVIE
# 201     201  tm117873             Hum Aapke Hain Koun..!  MOVIE
# 378     378   tm43399  Lagaan: Once Upon a Time in India  MOVIE
# 423     423   tm36475           Kabhi Khushi Kabhie Gham  MOVIE
# 428     428   tm29269                       Jodhaa Akbar  MOVIE
# 460     460   tm61056                     Dil Chahta Hai  MOVIE
# 485     485   tm82765                             Swades  MOVIE
# 490     490  tm144345                      Kal Ho Naa Ho  MOVIE
# 491     491   tm70222                   Sivaji: The Boss  MOVIE
# 495     495   tm25842                A Lion in the House  MOVIE
# 498     498   tm23441             Kabhi Alvida Naa Kehna  MOVIE
# ...

# %%
#Q26. How to get the top 5 most voted movies?

# %%
df['imdb_votes'].head(5)
# Out:
# 0    795222.0
# 1    530877.0
# 2    392419.0
# 3    391942.0
# 4     72895.0
# Name: imdb_votes, dtype: float64

# %%
df.nlargest(5,'imdb_votes')
# Out:
#      index        id                title   type  \
# 246    246   tm92641            Inception  MOVIE
# 101    101  tm122434         Forrest Gump  MOVIE
# 229    229       ts4         Breaking Bad   SHOW
# 662    662   tm41792     Django Unchained  MOVIE
# 104    104   tm57554  Saving Private Ryan  MOVIE
#
#                                            description  release_year  \
# 246  Cobb, a skilled thief who commits corporate es...          2010
# 101  A man with a low IQ has accomplished great thi...          1994
# 229  When Walter White, a New Mexico chemistry teac...          2008
# 662  With the help of a German bounty hunter, a fre...          2012
# 104  As U.S. troops storm the beaches of Normandy, ...          1998
#
#     age_certification  runtime_minutes    imdb_id  imdb_score  imdb_votes
# 246             PG-13              148  tt1375666         8.8   2268288.0
# 101             PG-13              142  tt0109830         8.8   1994599.0
# ...

# %%
#Q27. How to find correlation between runtime and imdb_score?

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes'],
#       dtype='object')

# %%
df[['runtime_minutes', 'imdb_score']].corr()
# Out:
#                  runtime_minutes  imdb_score
# runtime_minutes         1.000000   -0.159297
# imdb_score             -0.159297    1.000000

# %%
# Q28. How to filter out rows where IMDb score is missing?

# %%
df[df['imdb_score'].notnull()]
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
# Q29. How to add a column for IMDb score rating category?

# %%
df['score_category']= pd.cut(df['imdb_score'],bins=[0,5,7,10],labels=['low','medium','High'])

# %%
#Q30. How to count number of movies in each score category?

# %%
df['score_category'].value_counts()
# Out:
# score_category
# medium    2883
# High      1888
# low        512
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
# Q31. How to create a pivot table for average runtime by type and release_year?

# %%
pd.pivot_table(df,values='runtime_minutes',index='release_year',columns='type',aggfunc='mean')
# Out:
# type               MOVIE       SHOW
# release_year
# 1953          105.000000        NaN
# 1954          107.500000        NaN
# 1956          120.000000        NaN
# 1958           77.000000        NaN
# 1959          142.000000        NaN
# ...                  ...        ...
# 2018           98.185682  39.993007
# 2019           97.697228  39.528571
# 2020           95.066339  40.016000
# 2021           98.722628  39.235507
# 2022          100.611111  44.326087
#
# [66 rows x 2 columns]

# %%
# Q32. How to drop duplicate titles?
df.drop_duplicates(subset=['title'], inplace=True)

# %%
df.drop_duplicates(subset=['title'],inplace=True)

# %%
# 33. How to get movies with both high IMDb score (>8) and high votes (>100000)?

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
df[df['imdb_votes'] > 8 & (df['imdb_score']>100000)]
# Out:
#       index         id                               title   type  \
# 0         0    tm84618                         Taxi Driver  MOVIE
# 1         1   tm127384     Monty Python and the Holy Grail  MOVIE
# 2         2    tm70993                       Life of Brian  MOVIE
# 3         3   tm190788                        The Exorcist  MOVIE
# 4         4    ts22164        Monty Python's Flying Circus   SHOW
# ...     ...        ...                                 ...    ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279   5279  tm1014599                           Fine Wine  MOVIE
# 5280   5280  tm1045018                               Clash  MOVIE
# 5281   5281  tm1098060                      Shadow Parties  MOVIE
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
# Q34. How to calculate median IMDb score for each type?

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
df.groupby('type')['imdb_score'].median()
# Out:
# type
# MOVIE    6.4
# SHOW     7.2
# Name: imdb_score, dtype: float64

# %%
#Q35. How to plot runtime distribution by type?

# %%
sns.boxplot(x='type',y='runtime_minutes',data=df)
# Out:
# <Axes: xlabel='type', ylabel='runtime_minutes'>

# %%
#Q36. How to check number of null values per column in percentage?

(df.isnull().sum() /len(df)) *100
# Out:
# index                0.0
# id                   0.0
# title                0.0
# type                 0.0
# description          0.0
# release_year         0.0
# age_certification    0.0
# runtime_minutes      0.0
# imdb_id              0.0
# imdb_score           0.0
# imdb_votes           0.0
# score_category       0.0
# dtype: float64

# %%
#Q37. How to find the most common age certification?

# %%
df['age_certification'].mode()[0]
# Out:
# 999

# %%
#Q38. How to get top 3 movies for each type based on MDb score?

# %%
df.groupby('type').apply(lambda x: x.nlargest(3,'imdb_score'))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12188\2055536144.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('type').apply(lambda x: x.nlargest(3,'imdb_score'))
#             index        id                                 title   type  \
# type
# MOVIE 24       24   tm76557                        No Longer Kids  MOVIE
#       822     822  tm166740  Chhota Bheem & Krishna in Mayanagari  MOVIE
#       2685   2685  tm432327                     C/o Kancharapalem  MOVIE
# SHOW  622     622  ts160526                              Khawatir   SHOW
#       2787   2787  ts265844                              #ABtalks   SHOW
# ...

# %%
#Q39. How to create a bar plot of movie counts by age certification?

# %%
sns.countplot(x='age_certification',data=df)
# Out:
# <Axes: xlabel='age_certification', ylabel='count'>

# %%
#Q40. How to calculate year-on-year change in average IMDb score?

# %%
df.groupby('release_year')['imdb_score'].mean().pct_change()
# Out:
# release_year
# 1953         NaN
# 1954    0.095588
# 1956   -0.100671
# 1958    0.119403
# 1959   -0.106667
#           ...
# 2018    0.000722
# 2019   -0.000516
# 2020   -0.027658
# 2021   -0.003599
# 2022   -0.006606
# Name: imdb_score, Length: 66, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
# Q41. How to create a scatter plot of IMDb score vs votes?

# %%
sns.scatterplot(x='imdb_votes',y='imdb_score',data=df)
# Out:
# <Axes: xlabel='imdb_votes', ylabel='imdb_score'>

# %%
sns.scatterplot(x='imdb_score',y='imdb_votes', data=df)
# Out:
# <Axes: xlabel='imdb_score', ylabel='imdb_votes'>

# %%
#Q44. How to plot count of movies per release year?

# %%
df['release_year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='release_year'>

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
#Q45. How to find movies with titles starting with "The"?

# %%
df[df['title'].str.startswith("The")]
# Out:
#       index        id                       title   type  \
# 3         3  tm190788                The Exorcist  MOVIE
# 7         7   tm98978             The Blue Lagoon  MOVIE
# 9         9   tm67378           The Professionals  MOVIE
# 10       10   tm44204        The Guns of Navarone  MOVIE
# 13       13   tm96649             The Long Riders  MOVIE
# ...     ...       ...                         ...    ...
# 5200   5200  ts322267      The Big Shot Game Show   SHOW
# 5242   5242  ts308002             The Five Juanas   SHOW
# 5265   5265  tm993616  The Tambour of Retribution  MOVIE
# 5274   5274  tm878575         The Heartbreak Club  MOVIE
# 5275   5275  ts286386                 The Big Day   SHOW
#
#                                             description  release_year  \
# 3     12-year-old Regan MacNeil begins to adapt an e...          1973
# 7     Two small children and a ship's cook survive a...          1980
# ...

# %%
#Q46. How to calculate average runtime by age certification?

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
df.groupby('age_certification')['runtime_minutes'].mean()
# Out:
# age_certification
# 999       93.133657
# G         99.390476
# NC-17    100.230769
# PG       106.088608
# PG-13    108.800000
# R        106.116022
# TV-14     41.170507
# TV-G      26.055556
# TV-MA     43.498715
# TV-PG     35.286550
# TV-Y      16.648936
# TV-Y7     22.291262
# Name: runtime_minutes, dtype: float64

# %%
#Q47. How to find which year had the most releases?

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
df['release_year'].value_counts().idxmax()
# Out:
# np.int64(2019)

# %%
# Q48. How to find the longest movie ever made?

# %%
df.columns
# Out:
# Index(['index', 'id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime_minutes', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'score_category'],
#       dtype='object')

# %%
df.loc[df['runtime_minutes'].idxmax()]
# Out:
# index                                                               24
# id                                                             tm76557
# title                                                   No Longer Kids
# type                                                             MOVIE
# description          By coincidence, Ahmad discovers that his fathe...
# release_year                                                      1979
# age_certification                                                  999
# runtime_minutes                                                    235
# imdb_id                                                      tt8312792
# imdb_score                                                         9.0
# imdb_votes                                                       943.0
# score_category                                                    High
# Name: 24, dtype: object

# %%
#Q49. How to find the shortest movie with IMDb score above 8?

# %%
df[df['imdb_score'] >8].loc[df['runtime_minutes'].idxmax()]
# Out:
# index                                                               24
# id                                                             tm76557
# title                                                   No Longer Kids
# type                                                             MOVIE
# description          By coincidence, Ahmad discovers that his fathe...
# release_year                                                      1979
# age_certification                                                  999
# runtime_minutes                                                    235
# imdb_id                                                      tt8312792
# imdb_score                                                         9.0
# imdb_votes                                                       943.0
# score_category                                                    High
# Name: 24, dtype: object

# %%
#Q50. How to create a pie chart of type distribution?
df['type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#Q51. How to perform one-hot encoding for type?

# %%
pd.get_dummies(df,columns=['type'])
# Out:
#       index         id                               title  \
# 0         0    tm84618                         Taxi Driver
# 1         1   tm127384     Monty Python and the Holy Grail
# 2         2    tm70993                       Life of Brian
# 3         3   tm190788                        The Exorcist
# 4         4    ts22164        Monty Python's Flying Circus
# ...     ...        ...                                 ...
# 5278   5278  tm1040816         Momshies! Your Soul is Mine
# 5279   5279  tm1014599                           Fine Wine
# 5280   5280  tm1045018                               Clash
# 5281   5281  tm1098060                      Shadow Parties
# 5282   5282   ts271048  Mighty Little Bheem: Kite Festival
#
#                                             description  release_year  \
# 0     A mentally unstable Vietnam War veteran works ...          1976
# 1     King Arthur, accompanied by his squire, recrui...          1975
# ...

# %%
#Q52. How to impute missing IMDb scores using median per type?

# %%
df['imdb_scores'] =df.groupby('type')['imdb_score'].transform(lambda x:x.fillna(x.median()))

# %%
df['imdb_score'] = df.groupby('type')['imdb_score'].transform(lambda x: x.fillna(x.median()))

# %%
#Q53. How to detect outliers in runtime using IQR method?
